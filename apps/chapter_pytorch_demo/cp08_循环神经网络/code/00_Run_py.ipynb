# %% [markdown]
# # 运行py文件

# %%
# 运行 c6_RNN_中文训练.py


# %run c6_RNN_中文训练.py
# Out:
# Time consuming:  11.7384 秒
# perplexity 2.8, 489628.7 tokens/sec on cuda:0
# time<unk>tra<unk>eller杨钟说跟箫杨钟说啥塬看不见三井掌柜儿里开凿石窟杨家院子虎山东崖选中方位雇两个儿子一棵头井宗秀想摇头王
# tra<unk>eller动头说涡镇上老婆有人数说一颗队伍陈先生说蜂四处加互济会慌井掌柜吊唁拿出收据向井宗秀娘集资老婆子一说不
