# %% [markdown]
# ## [**简洁实现**]
#
# 高级API包含了前文介绍的所有配置细节，
# 所以我们可以直接实例化门控循环单元模型。
# 这段代码的运行速度要快得多，
# 因为它使用的是编译好的运算符而不是Python来处理之前阐述的许多细节。

# %%
import torch
from torch import nn
# from d2l import torch as d2l

import sys
sys.path.append("..")
import d2lzh_pytorch.torch_package  as d2l

# import d2lzh_pytorch.torch as d2l

# %%
batch_size = 32
num_steps = 35


train_iter, vocab = d2l.load_data_time_machine(batch_size, num_steps)
# Out:
# download函数将使用 /home/mylady/ai_data/d2l_data/data 作为缓存地址
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[3], line 5
#       1 batch_size = 32
#       2 num_steps = 35
# ----> 5 train_iter, vocab = d2l.load_data_time_machine(batch_size, num_steps)
#
# File ~/code/ai/DL-pytorch/apps/chapter_pytorch_demo/cp09_现代RNN/../d2lzh_pytorch/torch_package.py:873, in load_data_time_machine(batch_size, num_steps, use_random_iter, max_tokens)
#     864 def load_data_time_machine(batch_size, num_steps,
#     865                            use_random_iter=False, max_tokens=10000):
#     866     """Return the iterator and the vocabulary of the time machine dataset.
#     867     Defined in `sec_language_model`
#     868
#    (...)
#     871
#     872     """
# --> 873     data_iter = SeqDataLoader(
#     874         batch_size, num_steps, use_random_iter, max_tokens)
#     875     return data_iter, data_iter.vocab
#
# File ~/code/ai/DL-pytorch/apps/chapter_pytorch_demo/cp09_现代RNN/../d2lzh_pytorch/torch_package.py:857, in SeqDataLoader.__init__(self, batch_size, num_steps, use_random_iter, max_tokens)
#     855 else:
#     856     self.data_iter_fn = d2l.seq_data_iter_sequential
# --> 857 self.corpus, self.vocab = d2l.load_corpus_time_machine(max_tokens)
#     858 self.batch_size, self.num_steps = batch_size, num_steps
#
# File ~/code/ai/DL-pytorch/apps/chapter_pytorch_demo/cp09_现代RNN/../d2lzh_pytorch/torch_package.py:791, in load_corpus_time_machine(max_tokens)
#     783 def load_corpus_time_machine(max_tokens=-1):
#     784     """Return token indices and the vocabulary of the time machine dataset.
#     785     Defined in `sec_text_preprocessing`
#     786
#    (...)
#     789
#     790     """
# --> 791     lines = read_time_machine()
#     792     tokens = tokenize(lines, 'char')
#     793     vocab = Vocab(tokens)
#
# File ~/code/ai/DL-pytorch/apps/chapter_pytorch_demo/cp09_现代RNN/../d2lzh_pytorch/torch_package.py:665, in read_time_machine()
#     657 def read_time_machine():
#     658     """Load the time machine dataset into a list of text lines.
#     659     Defined in `sec_text_preprocessing`
#     660
#    (...)
#     663
#     664     """
# --> 665     with open(d2l.download('time_machine'), 'r') as f:
#     666         lines = f.readlines()
#     667     res = [re.sub('[^A-Za-z]+', ' ', line).strip().lower() for line in lines]
#
# File ~/code/ai/DL-pytorch/apps/chapter_pytorch_demo/cp09_现代RNN/../d2lzh_pytorch/torch_package.py:469, in download(name, cache_dir)
#     467 assert name in DATA_HUB, f"{name} does not exist in {DATA_HUB}."
#     468 url, sha1_hash = DATA_HUB[name]
# --> 469 os.makedirs(cache_dir, exist_ok=True)
#     470 fname = os.path.join(cache_dir, url.split('/')[-1])
#     471 if os.path.exists(fname):
#
# File ~/anaconda3/envs/d2l_pytorch_py10/lib/python3.10/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File ~/anaconda3/envs/d2l_pytorch_py10/lib/python3.10/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File ~/anaconda3/envs/d2l_pytorch_py10/lib/python3.10/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File ~/anaconda3/envs/d2l_pytorch_py10/lib/python3.10/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# PermissionError: [Errno 13] Permission denied: '/home/mylady'

# %%
vocab_size = len(vocab)
num_hiddens = 256
device = d2l.try_gpu()


num_epochs = 500
lr = 1

# %%
num_inputs = vocab_size

gru_layer = nn.GRU(num_inputs, num_hiddens)

model = d2l.RNNModel(gru_layer, len(vocab))
model = model.to(device)

# %%
# 训练
d2l.train_ch8(model, 
              train_iter, 
              vocab, 
              lr, 
              num_epochs, 
              device)
# Out:
# Time consuming:   8.0130 秒
# perplexity 1.0, 846952.2 tokens/sec on cuda:0
# time travelleryou can show black is white by argument said filby
# travelleryou can show black is white by argument said filby

# %% [markdown]
# ## 小结
#
# * 门控循环神经网络可以更好地捕获时间步距离很长的序列上的依赖关系。
# * 重置门有助于捕获序列中的短期依赖关系。
# * 更新门有助于捕获序列中的长期依赖关系。
# * 重置门打开时，门控循环单元包含基本循环神经网络；更新门打开时，门控循环单元可以跳过子序列。

# %%
model.state_dict()
