# %% [markdown]
# ## 执行当前code目录下的py文件

# %%
import torch

# %%
# %run c03_线性回归_简洁实现.py
# Out:
# epoch 1, loss 0.000213
# epoch 2, loss 0.000106
# epoch 3, loss 0.000106

# %%
# 执行 02-线性回归_从零开始实现


# %run c02_线性回归_从零开始实现.py
# Out:
# 训练前, 参数w:  tensor([[ 0.0106],
#         [-0.0015]], requires_grad=True)
# 训练前, 参数b:  tensor([0.], requires_grad=True)
# 训练中 .., 参数w:  tensor([[ 0.5885],
#         [-0.9136]], requires_grad=True)
# 训练中 .., 参数b:  tensor([1.1111], requires_grad=True)
# epoch 1, loss 9.227280
# 训练中 .., 参数w:  tensor([[ 1.0002],
#         [-1.5811]], requires_grad=True)
# 训练中 .., 参数b:  tensor([1.9274], requires_grad=True)
# epoch 2, loss 4.929896
# 训练中 .., 参数w:  tensor([[ 1.2929],
#         [-2.0691]], requires_grad=True)
# 训练中 .., 参数b:  tensor([2.5277], requires_grad=True)
# epoch 3, loss 2.635354
# w的估计误差: tensor([ 0.7071, -1.3309], grad_fn=<SubBackward0>)
# b的估计误差: tensor([1.6723], grad_fn=<RsubBackward1>)
