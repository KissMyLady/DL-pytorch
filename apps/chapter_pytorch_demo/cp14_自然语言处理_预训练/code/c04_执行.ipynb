# %% [markdown]
# # 一，执行.py文件

# %%
# 执行命令
# %run c4_预训练word2vec.py
# Out:
# Time consuming:   8.6086 s
# 耗时区间: ['1.7726', '1.6245', '1.6984', '1.6425'] s
# loss 0.661, 199344.2 tokens/sec on cuda:0

# %%
# 执行09


# %run c09_用于预训练BERT的数据集.py
# Out:
# 20256

# %%
# 执行10


# %run c10_预训练BERT.py
# Out:
# 耗时:  7.294373989105225
# MLM loss 5.420 NSP loss 0.757
# 3509.6 sentence pairs/sec on  [device(type='cuda', index=0)]
